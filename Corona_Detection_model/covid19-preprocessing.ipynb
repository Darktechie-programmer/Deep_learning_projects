# %%
## import the libraries
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("metadata.csv")
df.sample(10)
# Out:
#     patientid  offset  sex   age          finding RT_PCR_positive survival  \
# 576       306     2.0    M  40.0         COVID-19             NaN      NaN
# 725       382    90.0    F  30.0  Lobar Pneumonia             NaN      NaN
# 121        63     NaN  NaN   NaN         COVID-19               Y      NaN
# 57         24     NaN    M  75.0         COVID-19         Unclear      NaN
# 879       441     0.0    M   NaN             todo             NaN      NaN
# 546       290     1.0    F  63.0         COVID-19             NaN        Y
# 734       386    57.0    M   NaN             todo             NaN        Y
# 408       217     7.0    M  22.0         COVID-19             NaN      NaN
# 128        66     NaN  NaN   NaN         COVID-19               Y      NaN
# 373       207     NaN    M  62.0         COVID-19             NaN      NaN
#
#     intubated intubation_present went_icu in_icu needed_supplemental_O2  \
# ...

# %%
## chceck the covid patients
len(df[(df.finding == 'COVID-19') & ((df.view == 'AP') | (df.view == 'PA'))])
# Out:
# 311

# %%
image_path_covid = 'covid_image/'

# %%
# Check the total image in images folder
# df.shape
# covid_image = os.listdir(image_path_covid)
# len(covid_image)
# Out:
# (886, 29)

# %%
import os 
import shutil
target_dir = 'dataset/covid'

if not os.path.exists(target_dir):
    os.mkdir(target_dir)
    print("Created covid folder")

# %%
cnt = 0

for i,row in df.iterrows():
    if row['finding'] == 'COVID-19' and (row['view'] == 'AP' or row['view'] == 'PA') :
        filename = row['filename']
        image_path = os.path.join(image_path_covid,filename)
        image_copy_path = os.path.join(target_dir,filename)
        shutil.copy2(image_path,image_copy_path)
#         print('Moving image',cnt)
        cnt += 1
print(cnt)
# Out:
# Moving image 0
# Moving image 1
# Moving image 2
# Moving image 3
# Moving image 4
# Moving image 5
# Moving image 6
# Moving image 7
# Moving image 8
# Moving image 9
# Moving image 10
# Moving image 11
# Moving image 12
# Moving image 13
# Moving image 14
# Moving image 15
# Moving image 16
# Moving image 17
# Moving image 18
# Moving image 19
# Moving image 20
# Moving image 21
# Moving image 22
# Moving image 23
# Moving image 24
# Moving image 25
# Moving image 26
# Moving image 27
# Moving image 28
# Moving image 29
# Moving image 30
# Moving image 31
# Moving image 32
# Moving image 33
# Moving image 34
# Moving image 35
# Moving image 36
# Moving image 37
# Moving image 38
# Moving image 39
# Moving image 40
# Moving image 41
# Moving image 42
# Moving image 43
# Moving image 44
# Moving image 45
# Moving image 46
# Moving image 47
# Moving image 48
# Moving image 49
# Moving image 50
# Moving image 51
# Moving image 52
# Moving image 53
# Moving image 54
# Moving image 55
# ...
